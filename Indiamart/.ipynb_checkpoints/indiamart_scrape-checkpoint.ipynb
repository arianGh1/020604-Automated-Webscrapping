# %%
import time
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import csv
import pickle
import numpy as np
import pandas as pd
import pickle

from multiprocessing import Process
from multiprocessing import Pool
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %%
options = Options()

options.add_argument('--user-data-dir=/Users/Administrator/AppData/Local/Google/Chrome/User Data/') 
options.add_argument('--profile-directory=Profile 1')
options.add_argument("--disable-extensions")
options.add_argument('--disable-blink-features=AutomationControlled')
options.add_argument("--start-maximized")

options.add_argument('disable-infobars')
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("--remote-debugging-port=9222")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
options.add_argument(f'user-agent={user_agent}')

prefs = {
    "profile.default_content_setting_values.images": 2
}
options.add_experimental_option("prefs", prefs)

# Add a preference to disable image loading


capabilities = DesiredCapabilities.CHROME.copy()
capabilities['acceptSslCerts'] = True
capabilities['acceptInsecureCerts'] = True

# %%
file_path = 'urls.txt'

categories = []

with open(file_path, 'r') as file:
    for line in file:     
        category = line.strip()
        categories.append(category)
file_path = 'cities.txt'

cities = []

with open(file_path, 'r') as file:
    for line in file:     
        cityy = line.strip().lower()
        cities.append(cityy)
categories
# Out:
# ['https://dir.indiamart.com/impcat/pet-bottle-scrap.html',
#  'https://dir.indiamart.com/impcat/pp-scrap.html',
#  'https://dir.indiamart.com/impcat/hdpe-scrap.html',
#  'https://dir.indiamart.com/impcat/ld-plastic-scrap.html',
#  'https://dir.indiamart.com/impcat/hdpe-drum-scrap.html',
#  'https://dir.indiamart.com/impcat/waste-plastic.html',
#  'https://dir.indiamart.com/impcat/pvc-scrap.html',
#  'https://dir.indiamart.com/impcat/ldpe-scrap.html',
#  'https://dir.indiamart.com/impcat/pet-bottle-flake.html']

# %%
all_details = {}
index = 0
urls = []
names = []
history = 1
for count,category in enumerate(categories):
    driver = webdriver.Chrome(options=options , desired_capabilities=capabilities)
    for city in cities:
        if history%12==0 :
            driver.close()
            time.sleep(10)
            driver = webdriver.Chrome(options=options , desired_capabilities=capabilities)
            history += 1
        else:
            history += 1
        try:
            wb_address = category + "?grid_view=1"
            wb_address = wb_address.replace("impcat",city)
            driver.get(wb_address)
            
            time.sleep(2)
            html_text = driver.page_source
            soup = BeautifulSoup(html_text,"lxml")
            
            # If captcha appears
            while "check the box below to proceed" in html_text:
                html_text = driver.page_source
                soup = BeautifulSoup(html_text,"lxml")
                continue

            if "No results found for" in html_text:
                continue


            soup_old = ""
            print(f'Category Number:{count+1}/{len(categories)}----Dict_Length:{len(all_details)}',end='\r')
            while True:


                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                driver.implicitly_wait(3)

                try:

                    btn = driver.find_element(By.CLASS_NAME,"fm2")
                    driver.execute_script("arguments[0].click();",btn)

                except:

                    break
            html_text = driver.page_source
            soup = BeautifulSoup(html_text,"lxml")
            products = soup.find("div",class_="q_hm1 cnhdr fxmn")
            products = products.find("div",class_='lay-left')
            products = products.find("ul",class_="mListGrp w100 sid_df fww wlm mFrgn")
            sections = products.find_all("li")
            filtered_sections = []

            for section in sections:
                if section.has_attr('id'):
                    filtered_sections.append(section)

            for section in filtered_sections:
                details={}
                try:
                    name = section.find("h3").text
                    price = section.find("p").text
                    url = section.find("a")["href"].split(" ")[0]
                except:
                    continue

                if url in urls:
                    continue

                details["name"]= name
                details["price"] = price
                details["url"] = url
                details["category"] = category.split("/")[-1].split(".html")[0]


                all_details[index] = details
                index+=1
        except:
            continue

    driver.close()
# Out:
# Category Number:8/9----Dict_Length:12293
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[13], line 10
#       8 for city in cities:
#       9     if history%12==0 :
# ---> 10         driver.close()
#      11         time.sleep(3)
#      12         driver = webdriver.Chrome(options=options , desired_capabilities=capabilities)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:551, in WebDriver.close(self)
#     543 def close(self) -> None:
#     544     """Closes the current window.
#     545
#     546     :Usage:
#    (...)
#     549             driver.close()
#     550     """
# --> 551     self.execute(Command.CLOSE)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=116.0.5845.111)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF750C752A2+57122]
# 	(No symbol) [0x00007FF750BEEA92]
# 	(No symbol) [0x00007FF750ABE3AB]
# 	(No symbol) [0x00007FF750AAABE6]
# 	(No symbol) [0x00007FF750AAB31E]
# 	(No symbol) [0x00007FF750AAB250]
# 	(No symbol) [0x00007FF750A9CC5A]
# 	(No symbol) [0x00007FF750A9D85D]
# 	(No symbol) [0x00007FF750B20D24]
# 	(No symbol) [0x00007FF750B16FA0]
# 	(No symbol) [0x00007FF750AED2B1]
# 	(No symbol) [0x00007FF750AEE494]
# 	GetHandleVerifier [0x00007FF750F1EF82+2849794]
# 	GetHandleVerifier [0x00007FF750F71D24+3189156]
# 	GetHandleVerifier [0x00007FF750F6ACAF+3160367]
# 	GetHandleVerifier [0x00007FF750D06D06+653702]
# 	(No symbol) [0x00007FF750BFA208]
# 	(No symbol) [0x00007FF750BF62C4]
# 	(No symbol) [0x00007FF750BF63F6]
# 	(No symbol) [0x00007FF750BE67A3]
# 	BaseThreadInitThunk [0x00007FF8B4997974+20]
# 	RtlUserThreadStart [0x00007FF8B4ACA2F1+33]

# %%
df = pd.DataFrame().from_dict(all_details).T
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.to_csv("indiamart.csv")
df
# Out:
#                                           name          price  \
# 0               Grinded Green PET Bottle Scrap        ₹58/ Kg
# 1      Baled Pet Bottle Scrap - Natural Colour        ₹40/ Kg
# 2                  Multicolor PET Bottle Scrap        ₹12/ Kg
# 3           Aluminium Bottle Caps Scrap, 25 Kg        ₹65/ Kg
# 4            Pet Bottle Scrap, Pack Size: Bags  ₹30/ Kilogram
# ...                                        ...            ...
# 10651                      LDPE Plastic Scraps        ₹86/ Kg
# 10652        Pla granule, For Plastic Industry       ₹230/ Kg
# 10653          sintex Ldpe water tank grending
# 10654                         Ldpe Rolls Scrap
# 10655                      Ldpe Plastic Scraps
#
#                                                      url          category
# 0      https://www.indiamart.com/proddetail/green-pet...  pet-bottle-scrap
# 1      https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap
# 2      https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap
# 3      https://www.indiamart.com/proddetail/aluminium...  pet-bottle-scrap
# 4      https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap
# ...                                                  ...               ...
# 10651  https://www.indiamart.com/payal-enterprises-agra/        ldpe-scrap
# 10652  https://www.indiamart.com/proddetail/pla-granu...        ldpe-scrap
# 10653     https://www.indiamart.com/bn-traders-amritsar/        ldpe-scrap
# 10654         https://www.indiamart.com/sudhir-hardware/        ldpe-scrap
# 10655        https://www.indiamart.com/company/10910653/        ldpe-scrap
#
# [10656 rows x 4 columns]

# %%
df = pd.read_csv("indiamart.csv")
df.head()
# Out:
#    Unnamed: 0                                     name          price  \
# 0           0           Grinded Green PET Bottle Scrap        ₹58/ Kg
# 1           1  Baled Pet Bottle Scrap - Natural Colour        ₹40/ Kg
# 2           2              Multicolor PET Bottle Scrap        ₹12/ Kg
# 3           3       Aluminium Bottle Caps Scrap, 25 Kg        ₹65/ Kg
# 4           4        Pet Bottle Scrap, Pack Size: Bags  ₹30/ Kilogram
#
#                                                  url          category
# 0  https://www.indiamart.com/proddetail/green-pet...  pet-bottle-scrap
# 1  https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap
# 2  https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap
# 3  https://www.indiamart.com/proddetail/aluminium...  pet-bottle-scrap
# 4  https://www.indiamart.com/proddetail/pet-bottl...  pet-bottle-scrap

# %%
df["price"] = df["price"].apply(lambda x: str(x).strip(" "))
df["price"] = df["price"].apply(lambda x: str(x).lower())

df["price"] = df["price"].apply(lambda x: str(x).replace("Kilogram","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("Kg","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("KG","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("Kilogram(s)","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("KILOGRAMS","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("kgs","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("kilogram","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("kg(s)","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("per kg","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("kgs","kg"))

df["price"] = df["price"].apply(lambda x: str(x).replace("kg onwards","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("Kilogram Onwards","kg"))
df["price"] = df["price"].apply(lambda x: str(x).replace("TONNE","tonne"))
df["price"] = df["price"].apply(lambda x: str(x).replace("Tonne","tonne"))
df["price"] = df["price"].apply(lambda x: str(x).replace("metric ton(s)","tonne"))
df["price"] = df["price"].apply(lambda x: str(x).replace("ton","tonne") if str(x).split("/")[-1]==" ton" else x)
df["price"] = df["price"].apply(lambda x: str(x).replace("metric ton","tonne"))

df["price"] = df["price"].apply(lambda x: str(x).replace("Ton","tonne"))

# %%
df["metric"] = df["price"].apply(lambda x: str(x).split("/")[-1].strip())
df["metric"].value_counts().to_dict()
# Out:
# {'nan': 7791,
#  'kg': 2027,
#  'tonne': 83,
#  'color:  blue': 33,
#  'pet bottle scrap': 27,
#  'scrap': 25,
#  'pp scrap': 25,
#  'पीईटी बोतल स्क्रैप': 23,
#  'pvc scrap': 22,
#  'piece': 21,
#  'plastic bottle scrap': 20,
#  'प्लास्टिक स्क्रैप': 19,
#  'color:  white': 19,
#  'application:  plastic industry': 16,
#  'प्लास्टिक अपशिष्ट': 16,
#  'pet content:  96- 100%': 14,
#  'type:  hdpe': 13,
#  'pet content:  90- 95%': 12,
#  'ld plastic scrap': 12,
#  'एचडीपीई स्क्रैप': 12,
#  'color:  natural': 10,
#  'plastic waste': 10,
#  'pp content:  96- 100%': 10,
#  'country of origin:  made in india': 8,
#  'color:  mixed': 8,
#  'pp content:  90- 95%': 8,
#  'waste plastic': 7,
#  'color:  green': 7,
#  'pp plastic scrap': 7,
#  'hdpe drum scrap': 6,
#  'type:  pp': 6,
#  'waste type:  plastic waste': 5,
#  'ld plastic content:  96- 100%': 5,
#  'hdpe scrap': 5,
#  'color:  black': 5,
#  'color:  grey': 4,
#  'type:  pet': 4,
#  'application:  industrial': 4,
#  'plastic scrap': 4,
#  'color:  milky white': 4,
#  'rigid pvc scrap': 4,
#  'hdpe plastic scrap': 4,
#  'ld plastic content:  90- 95%': 3,
#  'color:  mixed colour': 3,
#  'color:  all colours': 3,
#  'pp plastic scraps': 3,
#  'long ton': 3,
#  'bottle scrap': 3,
#  'application:  reprocessed granules': 3,
#  'plastic scrap bottles': 2,
#  'पीवीसी रीग्रिंड स्क्रैप नीला, पैक: 25 kg, मैन्युफैक्चरिंग के लिए पीवीसी पाइप': 2,
#  'pet bottles scrap': 2,
#  'scrap bottle': 2,
#  'pet plastic bottle scraps': 2,
#  'सफेद प्लास्टिक पीपी स्क्रैप': 2,
#  'ड्रम स्क्रैप पैक: 50 kg, ड्रम बनाने के लिए': 2,
#  'bottel scrap': 2,
#  'processed scrap form:  grinded': 2,
#  'color:  all': 2,
#  'plastic bottle waste': 2,
#  '1 kg': 2,
#  'pp scraps': 2,
#  'pvc plastic scrap': 2,
#  'plastic scrap waste': 2,
#  'material:  plastic': 2,
#  'hdpe blue drum scrap': 2,
#  'plastic bottles scrap': 2,
#  'green bottel wast': 1,
#  'ld plastic waste scrap': 1,
#  'material:  reprocessing': 1,
#  '100kg': 1,
#  'waste type:  shredded plastic peel': 1,
#  'application:  bathroom, kitchen': 1,
#  'certificate': 1,
#  'waste plastic bags': 1,
#  'hdpe blue drum grinding chips': 1,
#  'नेक्सजन प्लास्टेक प्लांट वेस्ट पीईटी फ्लेक्स पैक: 25 kg, एक पालतू प्रीफॉर्म बनाने के लिए': 1,
#  'एचडीपीई का नीला ड्रम ग्राइंड, पैक: 25 kg': 1,
#  'pta ld liner plastic scrap': 1,
#  'ld polythene scrap': 1,
#  'ld p e scrap': 1,
#  'ld plastic bag scrap': 1,
#  'semi poly scrap': 1,
#  'प्लास्टिक स्क्रैप्स': 1,
#  'packaging type:  plastic bag': 1,
#  'classes timing:  morning batch': 1,
#  'plasitc प्लास्टिक स्क्रैप': 1,
#  'type:  ldpe': 1,
#  'ld palastic': 1,
#  'hm ld mix': 1,
#  'ld coating scrap': 1,
#  'ld plastic granule scrap': 1,
#  'hdpe drum grinding.rs-78+gst': 1,
#  'एचडीपीई प्लास्टिक स्क्रैप': 1,
#  'shape:  cylindrical': 1,
#  'hdpe blue drum scrap grinding': 1,
#  'hd blue drum plastic scraps': 1,
#  'drump scrap': 1,
#  'hd grinding ii': 1,
#  'plastic drum scrap': 1,
#  'hope blue drum scrap': 1,
#  'एचडीपीई प्लास्टिक का नीला ड्रम स्क्रैप पैक: 5 ton, कृषि पाइप और एचडीपीई पाइप के लिए': 1,
#  'blue drum grinding': 1,
#  'metal drum scraps': 1,
#  'barrel scrap': 1,
#  'एचडीपीई का नीला ड्रम ग्राइंडिंग, क्षमता: 150 से 200 l': 1,
#  'blue plastic drum': 1,
#  'piece(s)': 1,
#  'pieace': 1,
#  'hdpe': 1,
#  'waste type:  municipal waste panchayat waste': 1,
#  'pvc scrab white and gray': 1,
#  'pvc sole scrap': 1,
#  'pvc soft scrap': 1,
#  'waste pvc dairy': 1,
#  'application:  pyrolysis': 1,
#  'usage:  grinding, for cable, pipes, and profiles': 1,
#  'blue grinding pvc scrap': 1,
#  'condition:  second hand': 1,
#  'plastic waste bottles': 1,
#  'pvc scrap role...rijit': 1,
#  'plastic pvc scrap': 1,
#  'scrap pvc': 1,
#  'color:  gray': 1,
#  'pvc pulverized': 1,
#  'usage:  scrap': 1,
#  'fresh pvc scrap': 1,
#  'soft pvc scrap': 1,
#  'acrylic pvc scrap': 1,
#  'pvc sheet scrap': 1,
#  'coated scrap': 1,
#  'scrap form:  grinded': 1,
#  'पीवीसी फिल्म ग्रैंडिंग स्क्रैप, पैक: 25 kg': 1,
#  'pvc based plastic scraps': 1,
#  'black pvc pulverized': 1,
#  'barrel': 1,
#  'pvc scrap grinding': 1,
#  'packaging size:  40kg': 1,
#  'grinding pvc scrap': 1,
#  'pvc scrap 40 rs kg': 1,
#  'application:  scrap': 1,
#  'material:  pvc': 1,
#  'industrial ldpe scrap': 1,
#  'usage:  for making various utensils, in the designing of various machine': 1,
#  'packaging type:  bag': 1,
#  'gray rigid pvc scrap': 1,
#  'plastic can scrap': 1,
#  'waste plastic solution': 1,
#  'product type:  waste caps': 1,
#  'target location:  pan india': 1,
#  'all reject plastic': 1,
#  'racks palstic waste': 1,
#  'plastic chair waste scrap': 1,
#  'मल्टीकलर वेस्ट प्लास्टिक स्क्रैप': 1,
#  'waste plastic scrap': 1,
#  'waste plastic bottle scraps': 1,
#  'gulcose ld plastic waste': 1,
#  'ld print scrap': 1,
#  'ld natural waste': 1,
#  'रीसाइक्लिंग वेस्ट प्लास्टिक के लिए विनाोट पेल्टर': 1,
#  'pack type:  bag': 1,
#  'poly waste (droun) ret 38 par kg + gst and transport': 1,
#  'pvc waste plastic scrap': 1,
#  'plastic products waste': 1,
#  'प्लास्टिक का प्राकृतिक स्क्रैप': 1,
#  'plastic chair waste': 1,
#  'nylon plastic waste': 1,
#  'color:  gray & white': 1,
#  'pvc granding': 1,
#  'mode of shaping:  grinded': 1,
#  'mix pvc scrap': 1,
#  'medical scrap': 1,
#  'pvc cutting thool': 1,
#  'ट्विन स्क्रू शाफ्ट': 1,
#  'pvc grinding scrap': 1,
#  'पीवीसी स्क्रैप पैक: 40 kg': 1,
#  'pvc paver mould waste scrap': 1,
#  'multicolour baled ld plastic scrap': 1,
#  'hdep scrap': 1,
#  'packaging size:  50 kg': 1,
#  'pet scrap': 1,
#  'scrap plastic bottles': 1,
#  'hard pet scrap': 1,
#  'fridge bottle scrap': 1,
#  'plastic bottles scraps': 1,
#  'disposal bottle scrap': 1,
#  'pet bottles coloured': 1,
#  'pet scrap plastic': 1,
#  'waste type:  plastic bottle shreds': 1,
#  'pet bottle bale': 1,
#  'white bottle scrap': 1,
#  'pharma bottle scrap': 1,
#  'water bottle preform scrap': 1,
#  'bottle cap scrap': 1,
#  'waste pet bottle': 1,
#  'एल्युमिनियम कोवर स्क्रैप': 1,
#  'mixed color baled pet bottle scrap': 1,
#  'white pet bottles scrap': 1,
#  'capacity:  2 litre': 1,
#  'scrap bottle ma': 1,
#  'pet bottle scrap 2': 1,
#  'application:  for granuals making business': 1,
#  'pet bottle waste': 1,
#  'pet preform scrap': 1,
#  'bottle': 1,
#  'pet bottles scraps': 1,
#  'capacity:  500 ton': 1,
#  'pet bottle preform scrap': 1,
#  'pet neck scrap': 1,
#  'milky white pet bottle scrap': 1,
#  'usage:  making plastic products': 1,
#  'pet bottle scarp': 1,
#  'preform weight:  11-15 gms': 1,
#  'pet bottle scrab': 1,
#  'pet content:  90%': 1,
#  'plastic bottel scrap': 1,
#  'scrap bottale': 1,
#  'scrap bailed pet plastic bottles': 1,
#  'green bottle scrap': 1,
#  'bottle plastic scrap': 1,
#  'waste product of bottles': 1,
#  'capacity:  1 l': 1,
#  'crushed pet bottle': 1,
#  'plastic pet bottles bales scrap': 1,
#  'pack type:  bales': 1,
#  'scrap form:  crushed': 1,
#  'color:  natural colour': 1,
#  'application:  used for bottle strap': 1,
#  'packaging type:  baile': 1,
#  'pet bottle baddi': 1,
#  'material:  s.s': 1,
#  'color:  transparent': 1,
#  '1 litre:  11inches': 1,
#  'plastic pet bottle scrap': 1,
#  'material:  pet and wood': 1,
#  'plastic waste bottle scrap': 1,
#  'dew bottle scrape': 1,
#  'beer bottle scrap': 1,
#  'petbottle scrap': 1,
#  'no': 1,
#  'पीईटी बोतल पीवीसी स्क्रैप पैक: 50 kg': 1,
#  'pet bottle scrap bailing': 1,
#  'pet bottle clear bales': 1,
#  'hdpe regrind prewashed': 1,
#  'hdpe plastic grinding': 1,
#  'usage:  plastic products': 1,
#  'hdpe granule scrap': 1,
#  'application:  pipes': 1,
#  'एचडीपीई वॉश ग्राइंडिंग, पैक: 25 kg': 1,
#  'hdpe scrap chip': 1,
#  'pet content:  > 95%': 1,
#  'pack type:  customise': 1,
#  'hdpe plastic pipe scrap': 1,
#  'high density plastic drum scarp': 1,
#  'hdpe blue plastic scrap': 1,
#  'hdpe flakes': 1,
#  'color:  mix': 1,
#  'milky white hdpe scrap': 1,
#  'color:  mixed color': 1,
#  'plastic type:  hdpe': 1,
#  'hdpe black grinding scrap': 1,
#  'बल्क कपड़ा': 1,
#  'milky hdpe grinding scrap': 1,
#  'best quality hdpe regrind': 1,
#  'application:  blow molding': 1,
#  'hdpe blowing natural scrap': 1,
#  'hdpe grinding scraps': 1,
#  'hdpe plastics scrap': 1,
#  'color:  multicolored': 1,
#  'abs mixed plastic scrap': 1,
#  'hd dabba grinding': 1,
#  'एचडीपीई ग्रैन्यूल स्क्रैप, पैक साइज: 40 किलोग्राम': 1,
#  'hd plastic scrap': 1,
#  'pp plastic scarps': 1,
#  'smashed green bottle': 1,
#  'litil bottle scrap': 1,
#  'weight:  230 g': 1,
#  'pp raffia scrap bag': 1,
#  'bumfer grinding': 1,
#  'pp scarp': 1,
#  '25 kg': 1,
#  'reprocess pp scrap': 1,
#  'national pp scrap': 1,
#  'kilo gram': 1,
#  'mix color pp scrap': 1,
#  'pp color washed grinding': 1,
#  'प्लास्टिक का सफेद स्क्रैप': 1,
#  'hdpe plastic regrind scrap': 1,
#  'natural scrap': 1,
#  'pp raffia scrap': 1,
#  'pp scrap material': 1,
#  'red pp unwashed grinding': 1,
#  'pp-scrap': 1,
#  'pp laminate scrap': 1,
#  'p.p. artical scrap': 1,
#  'एचडी पाइप ग्राइंडिंग, पैक: बैग': 1,
#  'color:  black, blue': 1,
#  'diameter:  200 mm': 1,
#  'processed scrap form:  second grinded': 1,
#  'application:  injection moulding': 1,
#  'color:  na': 1}

# %%
df[df["metric"]=="kg"]["url"]
# Out:
# 0        https://www.indiamart.com/proddetail/green-pet...
# 1        https://www.indiamart.com/proddetail/pet-bottl...
# 2        https://www.indiamart.com/proddetail/pet-bottl...
# 3        https://www.indiamart.com/proddetail/aluminium...
# 4        https://www.indiamart.com/proddetail/pet-bottl...
#                                ...
# 10642    https://www.indiamart.com/proddetail/white-ldp...
# 10643    https://www.indiamart.com/proddetail/white-ldp...
# 10644    https://www.indiamart.com/proddetail/ldpe-plas...
# 10651    https://www.indiamart.com/payal-enterprises-agra/
# 10652    https://www.indiamart.com/proddetail/pla-granu...
# Name: url, Length: 2027, dtype: object

# %%
names_to_filter = ["kg", "tonne", "metric"]
filtered_df = df[df['metric'].isin(names_to_filter)]
filtered_df = filtered_df.reset_index(drop=True)

# %%
filtered_df.to_csv("filtered_indiamart.csv",index=False)

# %%
filtered_df
# Out:
#                                                    name     price
# 0                                     Inconel 690 Scrap  ₹550/ kg  \
# 1                                        Titanium Scrap  ₹250/ kg
# 2     Stainless Steel Plate Cut Scrap, 50 KG, Packag...  ₹100/ kg
# 3     Black Mild Steel Scrap, For Metal Industry, Pa...   ₹43/ kg
# 4     Aluminium Scrap Lithium Battery, Model Name/Nu...   ₹90/ kg
# ...                                                 ...       ...
# 3494  Dull White Polyester Monofilament Yarn, For Se...  ₹165/ kg
# 3495                                        Cotton Yarn  ₹110/ kg
# 3496                          100% Egyptian Cotton Yarn  ₹410/ kg
# 3497        Dull White Polyester Spun Yarn, For Weaving  ₹100/ kg
# 3498          Recycle Yarns Count Ranges From 2s To 40s  ₹130/ kg
#
#                                                     url          category
# 0     https://www.indiamart.com/proddetail/inconel-6...  Industrial Scrap  \
# 1     https://www.indiamart.com/proddetail/titanium-...  Industrial Scrap
# 2     https://www.indiamart.com/proddetail/stainless...  Industrial Scrap
# 3     https://www.indiamart.com/proddetail/mild-stee...  Industrial Scrap
# 4     https://www.indiamart.com/proddetail/scrap-lit...  Industrial Scrap
# ...                                                 ...               ...
# 3494  https://www.indiamart.com/proddetail/polyester...     Recycled Yarn
# 3495  https://www.indiamart.com/proddetail/cotton-ya...     Recycled Yarn
# 3496  https://www.indiamart.com/proddetail/100-egypt...     Recycled Yarn
# 3497  https://www.indiamart.com/proddetail/polyester...     Recycled Yarn
# 3498                                                NaN     Recycled Yarn
#
#      metric
# 0        kg
# 1        kg
# 2        kg
# 3        kg
# 4        kg
# ...     ...
# 3494     kg
# 3495     kg
# 3496     kg
# 3497     kg
# 3498     kg
#
# [3499 rows x 5 columns]
